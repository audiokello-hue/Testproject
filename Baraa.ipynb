# %% [markdown]
# <a href="https://colab.research.google.com/github/audiokello-hue/Testproject/blob/master/Baraa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###3
##math functions ( ceil, floor , trunc)

x= 56.89

print(isinstance(x, float))
# Out:
# True

# %%
## Control flow

## conditional statement
## Boolean
print(True)
print(False)
print(bool(123))
print(bool())
print(bool(0))
print(bool(None))

### use of any or all
email = ""
phone = "093628392"
username = ""

print(any([email,phone,username]))
print(all([email,phone,username]))

## operators

print(10==10)
print(10 !=10)

## Logical operators
 ## and | or
x = 3 < 5
y = 5 == 5

print(x and y)
print ( x or y)

cpu_usage = 70
memory_usage = 95
print(cpu_usage > 90 or memory_usage > 90)
print(cpu_usage > 90 and memory_usage > 90)

## not operator

x =  3 > 2
y = 5 == 8

print (not x)

### mixed conditions - uses and operator 1st then or operator , unless you are using brackets.

5 == 5
4 > 5
7 < 4

print( 5 == 5 or 4 > 5 and 7 > 4)

## not in | in
## is | is not
a = [1,2,3]
b = [1,2,3]

print ( a is b)
print ( a == b)
print (a is not b)
# Out:
# True
# False
# True
# False
# False
# False
# True
# False
# True
# False
# True
# True
# True
# False
# False
# True
# False
# True
# True

# %%
### """ challenges ,
    ##1. check if a user's name is not empty and the age is greater than or equal to 18
    ##2. check if the password is at least 8 characters long and does not contain spaces
    ##3. check if a user's email is not empy , contains "@", and ends with ".com"
    ##4. check if the user is either an admin or moderator, and either they're not banned or they've verified their email"""
