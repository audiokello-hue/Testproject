# %% [markdown]
# <a href="https://colab.research.google.com/github/audiokello-hue/Testproject/blob/master/module2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##---> Data structures

## Data types

"""int - used for counting
   float - represents measurements
   str - stores text
   bool - True / False"""

## Data categories

# categorical - data places observations in groups or categories.

""" Ordinal categorical data - have a meaningful order / rating
    Nominal - no natural order - colour , religion , blood group
    Binary - contain two categories """

# Quantitative data - reps amount or measurements.
""" Discrete data - countable values
    Contiuous - reps measurements"""

## ---> Structured vs Unstructured data

# Structured - stored in pre-defined form, organized in rows & coloumns.
# Unstructured - not in organized or fixed format.

## ----> CSV and JSON
""" CSV,comma separated values
    Name, Age, County
    Audi, 39 , Nairobi
    Martha, 30, Kisii"""

##
# Out:
# ' CSV,comma separated values\n    Name, Age, County \n    Audi, 39 , Nairobi\n    Martha, 30, Kisii'

# %%
# loading files using pandas # df - data frame

import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_train.csv")
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df.shape # rows and columns
# Out:
# (17000, 9)

# %%
df.columns # column names
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB
